# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['NAME','EIN'])

# %%
# Determine the number of unique values in each column.
charity_values = application_df.dtypes[application_df.dtypes != 'object'].index.tolist()
application_df[charity_values].nunique()
# Out:
# STATUS              2
# ASK_AMT          8747
# IS_SUCCESSFUL       2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_count = application_df.APPLICATION_TYPE.value_counts()
app_type_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_count[app_type_count < 1000].index)
for app in application_types_to_replace:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,'Other')
application_df.APPLICATION_TYPE.value_counts()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_df.CLASSIFICATION.value_counts()
class_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1283        1
# C1245        1
# C4200        1
# C8210        1
# C1900        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_count = application_df.CLASSIFICATION.value_counts().loc[lambda x : x>1]
class_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1600        5
# C1257        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1256        2
# C1267        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 1000].index)
for cls in classifications_to_replace:
    application_df.CLASSIFICATION =  application_df.CLASSIFICATION.replace(app,'Other')
application_df.CLASSIFICATION.value_counts()


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] =  application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2235
# C3000     1918
# C2100     1883
# C2150        1
# C1245        1
# C4200        1
# C1236        1
# C1248        1
# C4500        1
# C1580        1
# C2190        1
# C1732        1
# C2380        1
# C1900        1
# C2600        1
# C6100        1
# C2500        1
# C1283        1
# C4120        1
# C1728        1
# C5200        1
# C2561        1
# C1370        1
# C8210        1
# C1570        1
# C1820        1
# C2170        1
# C3700        1
# C2570        1
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
X = pd.get_dummies(application_df, columns=["APPLICATION_TYPE", "CLASSIFICATION"])
print(X.shape)
X.head(10)
# Out:
# (34299, 46)
#         AFFILIATION      USE_CASE  ORGANIZATION  STATUS     INCOME_AMT  \
# 0       Independent    ProductDev   Association       1              0
# 1       Independent  Preservation  Co-operative       1         1-9999
# 2  CompanySponsored    ProductDev   Association       1              0
# 3  CompanySponsored  Preservation         Trust       1    10000-24999
# 4       Independent     Heathcare         Trust       1  100000-499999
# 5       Independent  Preservation         Trust       1              0
# 6       Independent  Preservation         Trust       1  100000-499999
# 7       Independent  Preservation         Trust       1        10M-50M
# 8       Independent    ProductDev         Trust       1         1-9999
# 9  CompanySponsored    ProductDev   Association       1              0
#
#   SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0                      N     5000              1                       1
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop('IS_SUCCESSFUL', axis = 1)
y = application_df['IS_SUCCESSFUL']
X_train= X
y_train = y

X_training = pd.get_dummies(X_train)


# Split the preprocessed data into a training and testing dataset
y_test = application_df.IS_SUCCESSFUL.values
X_test = application_df.drop(columns='IS_SUCCESSFUL').values

X_testing = pd.get_dummies(X_test)

X_train, X_test, y_train, y_test = train_test_split(X,
                                                   y,
                                                   random_state=42,
                                                   stratify=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-8902b2bd80c1> in <module>
#      12 X_test = application_df.drop(columns='IS_SUCCESSFUL').values
#      13
# ---> 14 X_testing = pd.get_dummies(X_test)
#      15
#      16 X_train, X_test, y_train, y_test = train_test_split(X,
#
# ~\anaconda3\Python\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     903         result = concat(with_dummies, axis=1)
#     904     else:
# --> 905         result = _get_dummies_1d(
#     906             data,
#     907             prefix,
#
# ~\anaconda3\Python\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     927
#     928     # Series avoids inconsistent NaN handling
# ...

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a1eba94f3c2e> in <module>
#       3
#       4 # Fit the StandardScaler
# ----> 5 X_scaler = scaler.fit(X_train)
#       6
#       7 # Scale the data
#
# ~\anaconda3\Python\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\Python\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
# ...

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE

# Second hidden layer
#  YOUR CODE GOES HERE

# Output layer
#  YOUR CODE GOES HERE

# Check the structure of the model
nn.summary()

# %%
# Compile the model
#  YOUR CODE GOES HERE

# %%
# Train the model
#  YOUR CODE GOES HERE

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
